# %%
import sys
import pickle
sys.path.insert(0,'./')
# from importlib import reload

# %%
x={1:1,0:0}
1+ (x.get(1) or 0)
# Out:
# 2

# %%
from cov_3X2 import *
from fisher import *

# %%
#only for python3
import importlib
reload=importlib.reload

# %% [markdown]
# # Lensing X Lensing Correlation function covariance

# %% [markdown]
# ## Multiple redshift bins (Tomography)

# %%
import cov_utils
reload(cov_utils)
from cov_utils import *

# %%
import cov_3X2
reload(cov_3X2)
from cov_3X2 import *
from wigner_transform import *

# %%
import hankel_transform
from astropy.io import fits
reload(hankel_transform)
from hankel_transform import *

# %%
def readclxipm(filename):
    nz_bins=4
    na=20
    nz=np.int(nz_bins*(nz_bins+1.)/2.)
    print(nz)
    n_theta=ndesa=20
    tp_fits = fits.open(filename)[1].data #fitsio.FITS(filename)
    #xip = tp_fits['xip']
    #theta = xip['ang'][:ndesa]
    #thc = np.delete(theta,range(ndesa-na))

    ccl = tp_fits#[1]
    ccl_xip=ccl[:2*ndesa*nz,:2*ndesa*nz] #factor of 2 for xi_-
    #print ccl_xip[399,390:399]
    cov=np.zeros((2*nz*na,2*nz*na))
    for z1 in range(2*nz):
        for a1 in range(na):
            i1 = a1+z1*na
        ## The index in the original matrix is skewed because that matrix contains
        ## angles that have been cut. So 
            i1ccl = (a1+ndesa-na) + z1*ndesa
            for z2 in range(2*nz):
                for a2 in range(na):
                    i2 = a2 + z2*na
                ## The index in the original matrix is skewed because that matrix contains
                ## angles that have been cut. So 
                    i2ccl = (a2+ndesa-na) + z2*ndesa
                    cov[i1,i2]=ccl_xip[i1ccl,i2ccl]
    return cov

# %%
fname='/home/deep/data/DES/2pt_NG_mcal_final_7_11.fits'
DES_dat=fits.open(fname)

# %%
DES_dat[2].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   40 / length of dimension 1
# NAXIS2  =                  200 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    5 / number of table fields
# 2PTDATA =                    T
# EXTNAME = 'xip     '
# QUANT1  = 'G+R     '
# QUANT2  = 'G+R     '
# KERNEL_1= 'nz_source'
# KERNEL_2= 'nz_source'
# WINDOWS = 'SAMPLE  '
# N_ZBIN_1=                    4
# N_ZBIN_2=                    4
# N_ANG   =                   20
# TTYPE1  = 'BIN1    '
# TFORM1  = 'K       '
# TTYPE2  = 'BIN2    '
# TFORM2  = 'K       '
# TTYPE3  = 'ANGBIN  '
# TFORM3  = 'K       '
# TTYPE4  = 'VALUE   '
# TFORM4  = 'D       '
# TTYPE5  = 'ANG     '
# TFORM5  = 'D       '
# TUNIT5  = 'arcmin  '

# %%
cov_des=readclxipm(filename=fname)
# corr_des=cc.corr_matrix(cov_des)
# Out:
# 10

# %%
pz=Table.read(fname,format='fits',hdu=6)

# %%
f_sky=1321./(4*np.pi/d2r**2)
# f_sky=4182./(4*np.pi/d2r**2)

# %%
t=DES_dat[6].data
plot(t['Z_MID'],t['BIN1'])
plot(t['Z_MID'],t['BIN2'])
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#Setup redshift bins
zmin=0
zmax=3

nbins=4  # Number of tomographic bins
zs_bins=DES_bins(fname=fname)

ns0=np.sum(zs_bins['nz'])

# %%
do_xi=True
bin_xi=True
do_cov=True
bin_cl=False
th_min=2.5/60
th_max=250./60
n_th_bins=20
th_bins=np.logspace(np.log10(th_min),np.log10(th_max),n_th_bins+1)
th=np.logspace(np.log10(th_min),np.log10(th_max),n_th_bins*40)
thb=np.sqrt(th_bins[1:]*th_bins[:-1])

# %%
#Hankel Transform setup
l_max=1e4
l_min=2
l0=np.arange(l_min,l_max)
prune_theta=1
HT_kwargs={'l_min':l_min,  'l_max':l_max,
                        'theta_min':th_min*d2r*.9, 'theta_max':th_max*d2r,
                        'n_zeros':40000, 'prune_theta':prune_theta, 'm1_m2':[(2,2),(2,-2)]}
# %time HT=hankel_transform(**HT_kwargs)
# HT_kwargs2={'l_min':l_min,  'l_max':l_max,
#                         'theta_min':th_min*d2r*.9, 'theta_max':th_max*d2r,
#                         'n_zeros':40000, 'prune_theta':2, 'm1_m2':[(2,-2)]}#,(2,-2)]}

# %%
bin_xi=True
l_bins=None

# %%
use_window=True
do_sample_variance=True
SSV_cov=False
tidal_SSV=False
sigma_gamma=0.39/np.sqrt(2)

# %%
#use redshift bins from power spectrum part
XI_H =cov_3X2(zs_bins=zs_bins,l=l0,do_cov=do_cov,bin_cl=bin_cl,zg_bins=None,l_bins=l_bins,do_sample_variance=do_sample_variance,use_window=use_window,
               SSV_cov=SSV_cov,tidal_SSV_cov=tidal_SSV,do_xi=True,HT_kwargs=HT_kwargs,f_sky=f_sky,
               bin_xi=bin_xi,theta_bins=th_bins,sigma_gamma=sigma_gamma)#ns=np.inf)
# XI_H2 = lensing_lensing(zs_bins=zs_bins,l=l0,do_cov=do_cov,bin_cl=bin_cl,l_bins=l_bins,
#                SSV_cov=SSV_cov,tidal_SSV_cov=tidal_SSV,do_xi=True,HT_kwargs=HT_kwargs2,
#                bin_xi=bin_xi,theta_bins=th_bins)#ns=np.inf)
# Out:
# 06:26:06 WARNING:cross covariance not implemented with Hankel Transform. m1_m2s: [(2, 2), (2, -2)]
# 06:26:06 INFO:pruning theta, log_space:True n_f:1
# 06:26:06 INFO:pruned theta:115
# 06:26:06 INFO:nr:114
# 06:26:08 INFO:changed l_max to 11594.133199922566 to cover theta_min. j_nu=4
# 06:26:08 INFO:pruning theta, log_space:True n_f:1
# 06:26:08 INFO:pruned theta:131
# 06:26:08 INFO:nr:130

# %%
l_bins=np.logspace(1,3,40)

# %%
# Wigner Transform setup... Using high ell to test convergence
WT_L_kwargs={'l': np.arange(2,l_max*2,dtype='int'),'theta': th*d2r,'m1_m2':[(2,2),(2,-2)]}
# %time WT_L=wigner_transform(**WT_L_kwargs)

XI_W_L= cov_3X2(zs_bins=zs_bins,l=l0,do_cov=do_cov,bin_cl=bin_cl,l_bins=l_bins,zg_bins=None,do_sample_variance=do_sample_variance,use_window=use_window,
               SSV_cov=SSV_cov,tidal_SSV_cov=tidal_SSV,do_xi=True,HT=WT_L,sigma_gamma=sigma_gamma,f_sky=f_sky,
               bin_xi=bin_xi,theta_bins=th_bins)#ns=np.inf)
# Out:
# CPU times: user 429 ms, sys: 362 ms, total: 791 ms
# Wall time: 3min 1s

# %%
corr=('shear','shear')

# %%
# %time xiHG=XI_H.xi_tomo()
# %time xiWG_L=XI_W_L.xi_tomo()
# Out:
# [('shear', 'shear')]
# CPU times: user 14.2 s, sys: 28.9 ms, total: 14.2 s
# Wall time: 5.67 s
# [('shear', 'shear')]
# CPU times: user 14.3 s, sys: 46.5 ms, total: 14.4 s
# Wall time: 5.8 s

# %%
# %time xiH=xiHG['stack'].compute()
# %time xiH2=xiHG2['stack'].compute()
# Out:
# ./binning.py:55: RuntimeWarning: invalid value encountered in true_divide
#   xi_b/=bin_utils['norm']
# ./binning.py:63: RuntimeWarning: invalid value encountered in true_divide
#   cov_b/=bin_utils['norm_m'][2]
# 20 20 2
# CPU times: user 2min 7s, sys: 1.29 s, total: 2min 8s
# Wall time: 8.78 s

# %%
# %time xiW_L=xiWG_L['stack'].compute()
# Out:
# 20 20 2
# CPU times: user 1h 56min 20s, sys: 21.1 s, total: 1h 56min 41s
# Wall time: 7min 37s

# %% [raw]
# xiHG['stack'].visualize() #compute graph

# %% [raw]
# xiWG['stack'].visualize() #compute graph

# %% [raw]
# Scaling:
#
# ~ns_bins^4
# ~n_ell^1
#
# 10 tomo-bins, 10^4 ell points, 156 theta points, 100 z-> 3 mins on macbook

# %% [raw]
# with open('../cov_LL.pkl', 'rb') as f:
#      cov_LL=pickle.load(f) # use `pickle.loads` to do the reverse

# %%
f=1
cov_xiH_inv=np.linalg.inv(xiH['cov']*f)
print (np.sqrt(np.dot(xiH['xi'],np.dot(cov_xiH_inv,xiH['xi']))))

cov_xiWL_inv=np.linalg.inv(xiW_L['cov']*f)
print (np.sqrt(np.dot(xiW_L['xi'],np.dot(cov_xiWL_inv,xiW_L['xi']))))
# Out:
# nan
# 37.568079122359805

# %%
cc=XI_H.cov_utils
corrH=cc.corr_matrix(xiH['cov'])
pcolor(corrH,vmin=-1,vmax=1,cmap='seismic')
# xlabel(r'$\theta$ (degrees)')
# ylabel(r'$\theta$ (degrees)')
title('Hankel')
hlines(60,0,120)
vlines(60,0,120)
xticks([])
yticks([])


colorbar()
show()
# corrL=cc.corr_matrix(clL['cov'])
# pcolor(corrL,vmin=-1,vmax=1,cmap='seismic')
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 06:37:21 DEBUG:findfont: Matching :family=DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=42.0 to DejaVu Sans ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000

# %% [raw]
# corrH2=cc.corr_matrix(xiH2['cov'])
# pcolor(corrH2,vmin=-1,vmax=1,cmap='seismic')
# # xlabel(r'$\theta$ (degrees)')
# # ylabel(r'$\theta$ (degrees)')
# title('Hankel')
# colorbar()
# show()
# # corrL=cc.corr_matrix(clL['cov'])
# # pcolor(corrL,vmin=-1,vmax=1,cmap='seismic')

# %%
corr_des=cc.corr_matrix(cov_des)
pcolor(corr_des,vmin=-1,vmax=1,cmap='seismic')
# xlabel(r'$\theta$ (degrees)')
# ylabel(r'$\theta$ (degrees)')
hlines(n_th_bins*nbins*(nbins+1.)/2.,0,n_th_bins*nbins*(nbins+1.))
vlines(n_th_bins*nbins*(nbins+1.)/2.,0,n_th_bins*nbins*(nbins+1.))
xticks([])
yticks([])
title('DES')
show()
# corrL=cc.corr_matrix(clL['cov'])
# pcolor(corrL,vmin=-1,vmax=1,cmap='seismic')
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
cc=XI_W_L.cov_utils
corrWL=cc.corr_matrix(xiW_L['cov'])
pcolor(corrWL,vmin=-1,vmax=1,cmap='seismic')
title('Wigner')
show()
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [raw]
# m1m2=(2, 2, 2, -2)
# i=0
# j=0
# cov_t=xiWG['cov'][corr+corr][m1m2][(i,j,i,j)].compute()
# pcolor(cov_t['final'])
# colorbar()
# # print (cov_t)

# %%
import pyccl as ccl
cosmo_params={'h': 0.6774,
 'Omb': 0.0486,
 'Omd': 0.2589,
 's8': 0.817,
 'Om': 0.3075,
 'As': 2.12e-09,
 'mnu': 0.0,
 'Omk': 0.0,
 'tau': 0.06,
 'ns': 0.965,
 'w': -1,
 'wa': 0,
 'Oml': 0.6925}

ccl_cosmo = ccl.Cosmology(Omega_c=cosmo_params['Omd'], Omega_b=cosmo_params['Omb'], 
                      h=cosmo_params['h'], A_s=cosmo_params['As'], n_s=cosmo_params['ns'],)#m_nu=[0,0,0.06])

# %%
zs_bins[1]['pzdz'].sum(),zs_bins[1]['Norm']
# Out:
# (1.0000000000000002, 1.0000000000000002)

# %%
for i in np.arange(nbins):
    for j in np.arange(i,nbins):
#         errorbar(thb,xiHG['xi'][corr][m1m2][(i,j)].compute(),np.sqrt(np.diag(xiHG['cov'][corr+corr][m1m2+m1m2][(i,j,i,j)].compute()['final'])),fmt='o',label=(i,j))
#         plot(XI_W_L.l,xiWG_L['cl'][corr][(i,j)].compute(),marker='o',label=(i,j))
#         plot(XI_W_L.l,clWG_L['cl'][corr][(i,j)].compute(),marker='o',label=(i,j))
        lens1 = ccl.ClTracerLensing(ccl_cosmo, False, z=zs_bins[i]['z'], n=zs_bins[i]['pz'])
        lens2 = ccl.ClTracerLensing(ccl_cosmo, False, z=zs_bins[j]['z'], n=zs_bins[j]['pz'])
        cls = ccl.angular_cl(ccl_cosmo, lens1, lens2, XI_W_L.l)
#         xi_plus = ccl.correlation(ccl_cosmo, ell, cls, th,corr_type='L+', method='FFTLog')
#         plot(XI_W_L.l,cls)
        plot(XI_W_L.l,xiWG_L['cl'][corr][(i,j)].compute()/cls,label=(i,j))
        xscale('log')
#         yscale('log')
        xlabel(r'$\ell$')
        ylabel(r'$C_\ell$')
#         hlines(1,2,1000)
        legend()
#         ylim(0.9,1.1)
    show()
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 06:37:56 DEBUG:findfont: Matching :family=STIXGeneral:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXGeneral ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=STIXGeneral:style=italic:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXGeneral ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=STIXGeneral:style=normal:variant=normal:weight=bold:stretch=normal:size=35.0 to STIXGeneral ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf') with score of 0.000000
# 06:37:56 DEBUG:findfont: Matching :family=STIXNonUnicode:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXNonUnicode ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=STIXNonUnicode:style=italic:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXNonUnicode ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=STIXNonUnicode:style=normal:variant=normal:weight=bold:stretch=normal:size=35.0 to STIXNonUnicode ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf') with score of 0.000000
# 06:37:56 DEBUG:findfont: Matching :family=STIXSizeOneSym:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXSizeOneSym ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=STIXSizeTwoSym:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXSizeTwoSym ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=STIXSizeThreeSym:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXSizeThreeSym ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=STIXSizeFourSym:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXSizeFourSym ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=STIXSizeFiveSym:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to STIXSizeFiveSym ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=cmsy10:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to cmsy10 ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=cmr10:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to cmr10 ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=cmtt10:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to cmtt10 ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=cmmi10:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to cmmi10 ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=cmb10:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to cmb10 ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=cmss10:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to cmss10 ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=cmex10:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to cmex10 ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=DejaVu Sans:style=italic:variant=normal:weight=normal:stretch=normal:size=35.0 to DejaVu Sans ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf') with score of 0.150000
# 06:37:56 DEBUG:findfont: Matching :family=DejaVu Sans:style=normal:variant=normal:weight=bold:stretch=normal:size=35.0 to DejaVu Sans ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf') with score of 0.000000
# 06:37:56 DEBUG:findfont: Matching :family=DejaVu Sans Mono:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to DejaVu Sans Mono ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf') with score of 0.050000
# 06:37:56 DEBUG:findfont: Matching :family=DejaVu Sans Display:style=normal:variant=normal:weight=normal:stretch=normal:size=35.0 to DejaVu Sans Display ('/usr/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf') with score of 0.050000

# %%
m1m2=(2,2)
cp=['r','b','g','y']#sns.color_pallete()
for i in np.arange(nbins):
    for j in np.arange(i,nbins):
        errorbar(thb*60,thb*60*xiHG['xi'][corr][m1m2][(i,j)].compute(),
                 thb*60*np.sqrt(np.diag(xiHG['cov'][corr+corr][m1m2+m1m2][(i,j,i,j)].compute()['final'])),fmt='o',label=(i,j),color=cp[j])
        x=DES_dat[2].data['BIN1']==i+1
        x*=DES_dat[2].data['BIN2']==j+1
        th_t=DES_dat[2].data['ANG'][x]
        plot(th_t,th_t*DES_dat[2].data['VALUE'][x],color=cp[j])
    xscale('log')
    # yscale('log')
    xlabel(r'$\theta$ (arc min)')
    ylabel(r'$\xi_+$')
    legend(ncol=3)
    show()
# Out:
# ./binning.py:55: RuntimeWarning: invalid value encountered in true_divide
#   xi_b/=bin_utils['norm']
# ./binning.py:63: RuntimeWarning: invalid value encountered in true_divide
#   cov_b/=bin_utils['norm_m'][2]
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [raw]
# m1m2=(2,-2)
# for i in np.arange(nbins):
#     for j in np.arange(i,nbins):
#         errorbar(thb/d2r,thb/d2r*xiHG['xi'][corr][m1m2][(i,j)].compute(),thb/d2r*np.sqrt(np.diag(xiHG['cov'][corr+corr][m1m2+m1m2][(i,j,i,j)].compute()['final'])),fmt='o',label=(i,j))
# xscale('log')
# # yscale('log')
# xlabel(r'$\theta$ (arc min)')
# ylabel(r'$\xi_-$')
# legend(ncol=3)

# %%
m1m2=(2,2)
nth=20
i2=0
cs=['r','b','c','g','y']
for i in np.arange(nbins):
    j2=0
    for j in np.arange(i,nbins):
        plot(thb/d2r,np.sqrt(np.diag(xiWG_L['cov'][corr+corr][m1m2+m1m2][(i,j,i,j)].compute()['final'])),label=(i,j),
            c=cs[(i2+j2)%len(cs)])
        indx0=(i2+j2)*nth
        plot(thb/d2r,np.sqrt(np.diag(cov_des[indx0:indx0+nth,indx0:indx0+nth])),c=cs[(i2+j2)%len(cs)],ls='--')
        j2+=1
    i2+=1
xscale('log')
yscale('log')
xlabel(r'$\theta$ (arc min)')
ylabel(r'$\xi_+$')
legend(ncol=3)
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
th,Win2=XI_W_L.HT.projected_correlation(l_cl=XI_W_L.l,m1_m2=(2,2),cl=XI_W_L.cov_utils.Win)

# %%
plot(th/d2r,Win2)
xscale('log')
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plot(XI_W_L.l,XI_W_L.cov_utils.Win)
xscale('log')
yscale('log')
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [raw]
# m1m2=(2,2)
# nth=20
# i2=0
# cs=['r','b','c','g','y']
# for i in np.arange(nbins):
#     j2=0
#     for j in np.arange(i,nbins):
#         indx0=(i2+j2)*nth
#         plot(thb/d2r,np.sqrt(np.diag(xiWG_L['cov'][corr+corr][m1m2+m1m2][(i,j,i,j)].compute()['final']))/np.sqrt(np.diag(cov_des[indx0:indx0+nth,indx0:indx0+nth])),
#              label=(i,j),c=cs[(i2+j2)%len(cs)])
#
#         j2+=1
#     i2+=1
#
#     xscale('log')
#     # yscale('log')
#     xlabel(r'$\theta$ (arc min)')
#     ylabel(r'$\xi_+$')
#     legend(ncol=3)
#     show()

# %%
m1m2=(2,2)
nth=20
i2=0
cs=['r','b','c','g','y']
for i in np.arange(nbins):
    j2=0
    for j in np.arange(i,nbins):
        indx0=(i2+j2)*nth
        plot(thb/d2r,np.diag(xiHG['cov'][corr+corr][m1m2+m1m2][(i,j,i,j)].compute()['final'])*2/np.diag(cov_des[indx0:indx0+nth,indx0:indx0+nth]),
             label=(i,j),c=cs[(i2+j2)%len(cs)])
        
        j2+=1
    i2+=1
    
    xscale('log')
    # yscale('log')
    xlabel(r'$\theta$ (arc min)')
    ylabel(r'$\xi_+$')
    legend(ncol=3)
    show()
# Out:
# ./binning.py:63: RuntimeWarning: invalid value encountered in true_divide
#   cov_b/=bin_utils['norm_m'][2]
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
m1m2=(2,2)
nth=20
i2=0
cs=['r','b','c','g','y']
for i in np.arange(nbins):
    j2=0
    for j in np.arange(i,nbins):
        indx0=(i2+j2)*nth
        plot(thb/d2r,np.sqrt(np.diag(xiWG_L['cov'][corr+corr][m1m2+m1m2][(i,j,i,j)].compute()['final']))/np.sqrt(np.diag(xiHG['cov'][corr+corr][m1m2+m1m2][(i,j,i,j)].compute()['final'])),
             label=(i,j),c=cs[(i2+j2)%len(cs)])
        
        j2+=1
    i2+=1
    
    xscale('log')
    # yscale('log')
    xlabel(r'$\theta$ (arc min)')
    ylabel(r'$\xi_+$')
    legend(ncol=3)
    show()
# Out:
# ./binning.py:63: RuntimeWarning: invalid value encountered in true_divide
#   cov_b/=bin_utils['norm_m'][2]
# /usr/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
crash
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-2a418ad8f387> in <module>()
# ----> 1 crash
#
# NameError: name 'crash' is not defined

# %% [markdown]
# # Galaxy X Lensing Correlation function covariance

# %%
import galaxy_utils
reload(galaxy_utils)
from galaxy_utils import *

# %%
import cov_utils
reload(cov_utils)
from cov_utils import *

# %%
import cov_3X2
reload(cov_3X2)
from cov_3X2 import *
from wigner_transform import *

# %%
#Setup redshift bins
zmin=0.3
zmax=2

z=np.linspace(0,5,200)
pzs=lsst_pz_source(z=z)
x=z<zmax
x*=z>zmin
z=z[x]
pzs=pzs[x]

ns0=26 #26+np.inf #ns=inf means shape noise is zero
nbins=5  # Number of tomographic bins
z_sigma=0.01
zs_bins=source_tomo_bins(zp=z,p_zp=pzs,ns=ns0,nz_bins=nbins,
                         ztrue_func=ztrue_given_pz_Gaussian,zp_bias=np.zeros_like(z),
                        zp_sigma=z_sigma*np.ones_like(z))

ng0=10 #26+np.inf #ns=inf means shape noise is zero
# nbins=3  # Number of tomographic bins
z_sigma=0.1
zg_bins=source_tomo_bins(zp=z,p_zp=pzs,ns=ns0,nz_bins=nbins,
                         ztrue_func=ztrue_given_pz_Gaussian,zp_bias=np.zeros_like(z),
                        zp_sigma=z_sigma*np.ones_like(z))


# nbins=np.int(nbins*(nbins+1.)/2.)
# zl_bins=lens_wt_tomo_bins(zp=z,p_zp=pzs,ns=ns0,nz_bins=nbins,z_bins=np.linspace(zmin,1.5,nbins),
#                           ztrue_func=ztrue_given_pz_Gaussian,zp_bias=np.zeros_like(z),
#                         zp_sigma=z_sigma*np.ones_like(z))

SSV_cov=True
tidal_SSV=False

# %%
do_xi=True
bin_xi=True
bin_cl=True
th_min=1./60
th_max=10
n_th_bins=20
n_th=160
th=np.logspace(np.log10(th_min*2),np.log10(th_max),n_th)
th_bins=np.logspace(np.log10(th_min*2),np.log10(th_max),n_th_bins+1)
thb=np.sqrt(th_bins[1:]*th_bins[:-1])

# %%
corr_ggl=('galaxy','shear')
corr_gg=('galaxy','galaxy')
corr_ll=('shear','shear')
m1m2=(0,2)
m1m2_gg=(0,0)

# %% [raw]
# #Hankel Transform setup
# # l_max=1e4
# # l_min=2
# HT_kwargs={'l_min':l_min,  'l_max':l_max,
#                         'theta_min':th_min*d2r*.9, 'theta_max':th_max*d2r,
#                         'n_zeros':40000, 'prune_theta':2, 'm1_m2':[m1m2]}
# HT=hankel_transform(**HT_kwargs,logger=XI_W.logger)

# %%
# Wigner Transform setup
l_W=np.arange(2,l_max,dtype='int')
WT_kwargs={'l':l_W ,'theta':th*d2r ,'m1_m2':[(0,0),(0,2),(2,2),(2,-2)]}
# %time WTggl=wigner_transform(**WT_kwargs)

XI_W= cov_3X2(zs_bins=zs_bins,l=l0,do_cov=do_cov,bin_cl=bin_cl,l_bins=l_bins,zg_bins=zg_bins,
               SSV_cov=SSV_cov,tidal_SSV_cov=tidal_SSV,do_xi=do_xi,HT=WTggl,
#               HT_kwargs=HT_kwargs,
               bin_xi=bin_xi,theta_bins=th_bins)#ns=np.inf)

# %%
# %time cl_Wggl=XI_W.cl_tomo(corrs=[corr_ll,corr_ggl,corr_gg])

# %%
# %time xiWggl=XI_W.xi_tomo(corrs=[corr_ll,corr_ggl,corr_gg])
# %time xiW_ggl=xiWggl['stack'].compute()

# %%
cl_Wggl['cl'][corr_ggl][(0,0)].compute().min()

# %%
cl_Wggl['cl'].keys()

# %%
cl_Wggl['cov'][corr_ggl+corr_ggl][(0,0,0,1)]['G1423'].compute().min()

# %% [raw]
# for i in np.arange(nbins):
#     for j in np.arange(i,nbins):
#         plot(l0,cl_Wggl['cl_b'][corr_ggl][(i,j)].compute(),label=(i,j))
#         xscale('log')
#         yscale('log')
#         xlabel(r'$\ell$')
#         ylabel(r'$C_\ell$')
#         legend()
# #         show()

# %% [raw]
# ij=(0,0)
# covv=cl_Wggl['cov'][corr_ggl+corr_ggl][ij+ij].compute()#['final']
# corr=cc.corr_matrix(covv['final'])
# pcolor(corr,vmin=-1,vmax=1,cmap='seismic')

# %%
for i in np.arange(nbins):
    for j in np.arange(i,nbins):
        plot(thb,xiWggl['xi'][corr_ggl][m1m2][(i,j)].compute(),label=(i,j))
        plot(thb,xiWggl['xi'][corr_gg][m1m2_gg][(i,j)].compute(),ls='--')
        xscale('log')
        yscale('log')
        xlabel(r'$\theta$ (degrees)')
        ylabel(r'$\xi$')
        legend()
show()

# %%
for i in np.arange(nbins):
    for j in np.arange(0,nbins):
        errorbar(thb,xiWggl['xi'][corr_ggl][m1m2][(i,j)].compute(),np.sqrt(np.diag(xiWggl['cov'][corr_ggl+corr_ggl][m1m2+m1m2][(i,j,i,j)].compute()['final'])),fmt='o',label=(i,j))
xscale('log')
yscale('log')
xlabel(r'$\theta$ (degrees)')
ylabel(r'$\xi$')
legend()

# %%
for i in np.arange(nbins):
    for j in np.arange(i,nbins):
        errorbar(thb,xiWggl['xi'][corr_gg][m1m2_gg][(i,j)].compute(),np.sqrt(np.diag(xiWggl['cov'][corr_ggl+corr_ggl][m1m2+m1m2][(i,j,i,j)].compute()['final'])),fmt='o',label=(i,j))
xscale('log')
yscale('log')
xlabel(r'$\theta$ (degrees)')
ylabel(r'$\xi$')
legend()

# %%
nbins=5

# %%
cc=XI_W.cov_utils
corrW=cc.corr_matrix(xiW_ggl['cov'])
pcolor(corrW,vmin=-1,vmax=1,cmap='seismic')
# xlabel(r'$\theta$ (degrees)')
# ylabel(r'$\theta$ (degrees)')
x1=20.*nbins*(nbins+1)/2.
x2=20.*nbins*nbins
hlines(x1,0,len(corrW),lw=2)
vlines(x1,0,len(corrW),lw=2)
hlines(x1*2,0,len(corrW),lw=2)
vlines(x1*2,0,len(corrW),lw=2)
hlines(x1*2+x2,0,len(corrW),lw=2)
vlines(x1*2+x2,0,len(corrW),lw=2)
title('Wigner')
xticks([])
yticks([])
show()
# corrL=cc.corr_matrix(clL['cov'])
# pcolor(corrL,vmin=-1,vmax=1,cmap='seismic')

# %% [raw]
# pcolor(corrW.T,vmin=-1,vmax=1,cmap='seismic')

# %%
import healpy as hp
hp.nside2npix(1024)
