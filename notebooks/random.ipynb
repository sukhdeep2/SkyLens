# %%
from colossus.cosmology import cosmology
from colossus.lss import mass_function
cosmology.setCosmology('WMAP9')

# %%
??mass_function.massFunction

# %%
M=np.logspace(11,16,100)
mfunc_so = mass_function.massFunction(M, 0.0, mdef = '200c', model = 'tinker08')
mfunc_so2 = mass_function.massFunction(M/1.1, 0.0, mdef = '200c', model = 'tinker08')

# %%
??cosmology

# %%
params = cosmology.cosmologies['planck18']

# %%
params['Om0']=.2

# %%
cosmology.setCosmology(cosmo_name='planck18',params=params)
mfunc_so3 = mass_function.massFunction(M, 0.0, mdef = '200c', model = 'tinker08')

# %%
cosmology.current_cosmo.
# Out:
# 0.8102

# %%
plot(M,mfunc_so)
plot(M,mfunc_so2)
plot(M,mfunc_so3)
loglog()
# Out:
# []

# %%
plot(M,mfunc_so/mfunc_so2)
plot(M,mfunc_so/mfunc_so3)
# plot(M,mfunc_so2)
loglog()
# Out:
# []
