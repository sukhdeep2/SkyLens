# %%
import sys
import pyccl as ccl
import pickle
import camb
sys.path.insert(0,'./')
# from importlib import reload

# %%
from distributed import LocalCluster
from dask.distributed import Client  # we already had this above
#http://distributed.readthedocs.io/en/latest/_modules/distributed/worker.html
c=LocalCluster(n_workers=1,processes=False,memory_limit='20gb',threads_per_worker=14,memory_spill_fraction=.99,
               memory_monitor_interval='2000ms')
client=Client(c)
# Out:
# /usr/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
from cov_3X2 import *
from lsst_utils import *

# %%
#only for python3
import importlib
reload=importlib.reload

# %%
zs=lsst_source_tomo_bins()
# Out:
# ns0:  27.0

# %% [markdown]
# # Power Spectrum covariance

# %%
#setup parameters
lmax_cl=5000
lmin_cl=2
l0=np.arange(lmin_cl,lmax_cl)

lmin_cl_Bins=lmin_cl+10
lmax_cl_Bins=lmax_cl-10
Nl_bins=40
l_bins=np.int64(np.logspace(np.log10(lmin_cl_Bins),np.log10(lmax_cl_Bins),Nl_bins))
lb=np.sqrt(l_bins[1:]*l_bins[:-1])

l=np.unique(np.int64(np.logspace(np.log10(lmin_cl),np.log10(lmax_cl),Nl_bins*20))) #if we want to use fewer ell

do_cov=True
bin_cl=True

SSV_cov=True
tidal_SSV_cov=False
Tri_cov=True

bin_xi=True
theta_bins=np.logspace(np.log10(1./60),1,20)

# %% [markdown]
# ##  Test with 1 redshift bin

# %%
f_sky=0.35

# %%
z0=1 #1087
zs_bin1=source_tomo_bins(zp=[z0],p_zp=np.array([1]),ns=30,use_window=True,unit_win=True,f_sky=f_sky)
zs_bin1N=source_tomo_bins(zp=[z0],p_zp=np.array([1]),ns=10,use_window=True,unit_win=True,f_sky=f_sky)
# Out:
# Win gen: step size 768
# ./cov_utils.py:60: RuntimeWarning: invalid value encountered in true_divide
#   Win0=2*jn(1,l_th)/l_th
# ./angular_power_spectra.py:23: RuntimeWarning: divide by zero encountered in true_divide
#   self.cl_f=(l+0.5)**2/(l*(l+1.)) # cl correction from Kilbinger+ 2017
# cl dict done
# Win gen: step size 768
# cl dict done

# %%
zs_bin1[0].keys()
# Out:
# dict_keys(['z', 'dz', 'nz', 'ns', 'W', 'pz', 'pzdz', 'Norm', 'b1', 'AI', 'AI_z', 'mag_fact', 'lm', 'Gkernel', 'Gkernel_int', 'gkernel', 'gkernel_int', 'kernel_int', 'window', 'window_alm', 'window_alm_noise'])

# %%
# loglog(zs_bin1[0]['window_cl'])
loglog(hp.alm2cl(zs_bin1[0]['window_alm']))
# Out:
# 06:14:41 WARNING:findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
hp.mollview(zs_bin1[0]['window'])
# Out:
# /usr/lib/python3.7/site-packages/healpy/projaxes.py:1194: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):
# /usr/lib/python3.7/site-packages/healpy/projaxes.py:1153: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if matplotlib.cbook.iterable(value):
# 06:14:42 WARNING:findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
import cov_3X2
reload(cov_3X2)
from cov_3X2 import *

# %%
# bin_cl=False
if not bin_cl:
    lb=l0
    l=l0

# %%
from astropy.cosmology import Planck15 as cosmo

# %%
import pyccl as ccl
cosmo_params={'h': 0.6774,
 'Omb': 0.0486,
 'Omd': 0.2589,
 's8': 0.817,
 'Om': 0.3075,
 'As': 2.12e-09,
 'mnu': 0.06,
 'Omk': 0.0,
 'tau': 0.06,
 'ns': 0.965,
 'w': -1,
 'wa': 0,
 'Oml': 0.6925}

# %%
use_window=False

# %%
power_spectra_kwargs={'pk_func':'baryon_pk'}

# %%
#on nersc try /global/cscratch1/sd/sukhdeep/temp/
# only needed if you are playing with window calculations, kappa_win below
wigner_files={}
wigner_files[0]= 'temp/dask_wig3j_l6500_w2100_0_reorder.zarr'
wigner_files[2]= 'temp/dask_wig3j_l6500_w1100_2_reorder.zarr'

# %%
#use all ell
kappa0=cov_3X2(zs_bins=zs_bin1,do_cov=do_cov,bin_cl=bin_cl,l_bins=l_bins,l=l0, zg_bins=None,
                                       use_window=use_window,Tri_cov=Tri_cov,
                                       SSV_cov=SSV_cov,tidal_SSV_cov=tidal_SSV_cov,f_sky=f_sky,
                                       )
kappa1=cov_3X2(zs_bins=zs_bin1N,do_cov=do_cov,bin_cl=bin_cl,l_bins=l_bins,l=l0, zg_bins=None,
                                       use_window=use_window,Tri_cov=Tri_cov,
                                       SSV_cov=SSV_cov,tidal_SSV_cov=tidal_SSV_cov,f_sky=f_sky,
                                       )


#to test calculation using proper windows, in SSC.
# kappa_win=cov_3X2(zs_bins=zs_bin1,do_cov=do_cov,bin_cl=bin_cl,l_bins=l_bins,l=l0, zg_bins=None,
#                                        use_window=True,Tri_cov=Tri_cov,store_win=True,
#                                        SSV_cov=SSV_cov,tidal_SSV_cov=tidal_SSV_cov,f_sky=f_sky,
#                                        wigner_files=wigner_files)
# Out:
# Win gen: step size 807
# Win gen: step size 807

# %%
#get compute graphs
# %time cl0G=kappa0.cl_tomo() 
# %time cl0G1=kappa1.cl_tomo() 
# %time cl0G_win=kappa_win.cl_tomo()
# Out:
# cl dict done
# CPU times: user 16.5 s, sys: 49.9 ms, total: 16.5 s
# Wall time: 7.44 s
# cl dict done
# CPU times: user 16.6 s, sys: 42.1 ms, total: 16.7 s
# Wall time: 7.38 s

# %%
# %time cl0=cl0G['stack'].compute()
# %time cl1=cl0G1['stack'].compute()
# %time cl0_win=cl0G_win['stack'].compute()
# %time clB=clBG['stack'].compute()
# Out:
# [4.58585244e-16 9.72005109e-16 1.33269396e-15 ... 5.40396202e-20
#  5.40325311e-20 5.40254446e-20] [4.58585244e-16 9.72005109e-16 1.33269396e-15 ... 5.40396202e-20
#  5.40325311e-20 5.40254446e-20] 1
# 0 True
# True
# 2 True
# True
# 4 True
# True
# CPU times: user 7.21 s, sys: 393 ms, total: 7.6 s
# Wall time: 7.27 s
# [4.75062974e-16 9.95928341e-16 1.36068154e-15 ... 3.76750582e-19
#  3.76731863e-19 3.76713151e-19] [4.75062974e-16 9.95928341e-16 1.36068154e-15 ... 3.76750582e-19
#  3.76731863e-19 3.76713151e-19] 1
# 0 True
# True
# 2 True
# True
# 4 True
# True
# CPU times: user 7.21 s, sys: 347 ms, total: 7.56 s
# Wall time: 7.23 s

# %%
bi=(0,0)

# %%
corr2=kappa0.cov_utils.corr_matrix(cl0['cov'])
pcolor(lb,lb,corr2,vmin=-1,vmax=1,cmap='seismic')
xscale('log')
yscale('log')

# %%
#again get Cl and cov, this time by referencing the particular bin
cl0={}
corr=('shear','shear')
# %time cl0['cl0']=cl0G['cl'][corr][(0,0)].compute()
# %time cl0['cl']=cl0G['cl_b'][corr].compute()
# %time cl0['cov']=cl0G['cov'][corr+corr][(0,0,0,0)].compute()#kappa0.compute_cov_tomo(cl0G['cov'])

#again get Cl and cov, this time by referencing the particular bin
cl1={}
corr=('shear','shear')
# %time cl1['cl0']=cl0G1['cl'][corr][(0,0)].compute()
# %time cl1['cl']=cl0G1['cl_b'][corr].compute()
# %time cl1['cov']=cl0G1['cov'][corr+corr][(0,0,0,0)].compute()#kappa0.compute_cov_tomo(cl0G['cov'])
# Out:
# CPU times: user 12.9 ms, sys: 9.98 ms, total: 22.9 ms
# Wall time: 19.1 ms
# CPU times: user 10.7 ms, sys: 20 µs, total: 10.7 ms
# Wall time: 9.35 ms
# [4.58585244e-16 9.72005109e-16 1.33269396e-15 ... 5.40396202e-20
#  5.40325311e-20 5.40254446e-20] [4.58585244e-16 9.72005109e-16 1.33269396e-15 ... 5.40396202e-20
#  5.40325311e-20 5.40254446e-20] 1
# 0 True
# True
# 2 True
# True
# 4 True
# True
# CPU times: user 7.13 s, sys: 380 ms, total: 7.5 s
# Wall time: 7.17 s
# CPU times: user 14.6 ms, sys: 3.24 ms, total: 17.8 ms
# Wall time: 16.1 ms
# CPU times: user 25.8 ms, sys: 3.22 ms, total: 29 ms
# Wall time: 32 ms
# [4.75062974e-16 9.95928341e-16 1.36068154e-15 ... 3.76750582e-19
#  3.76731863e-19 3.76713151e-19] [4.75062974e-16 9.95928341e-16 1.36068154e-15 ... 3.76750582e-19
#  3.76731863e-19 3.76713151e-19] 1
# 0 True
# True
# 2 True
# True
# 4 True
# True
# CPU times: user 7.21 s, sys: 383 ms, total: 7.59 s
# Wall time: 7.28 s

# %%
# compute signal/noise
cov_inv=np.linalg.inv(cl0['cov']['final_b'])
SN2=(np.dot(cl0['cl'][bi],np.dot(cov_inv,cl0['cl'][bi])))

cov_inv=np.linalg.inv(cl0['cov']['G_b'])
SN2G=(np.dot(cl0['cl'][bi],np.dot(cov_inv,cl0['cl'][bi])))


np.sqrt(SN2),np.sqrt(SN2G)
# Out:
# (135.70567243775858, 461.9421326888074)

# %%
# compute signal/noise
cov_inv=np.linalg.inv(cl1['cov']['final_b'])
SN21=(np.dot(cl1['cl'][bi],np.dot(cov_inv,cl1['cl'][bi])))

cov_inv=np.linalg.inv(cl1['cov']['G_b'])
SN2G1=(np.dot(cl1['cl'][bi],np.dot(cov_inv,cl1['cl'][bi])))


np.sqrt(SN21),np.sqrt(SN2G1)
# Out:
# (118.28518694562192, 247.70751023067137)

# %% [raw]
# #again get Cl and cov, this time by referencing the particular bin
# cl0_win={}
# corr=('shear','shear')
# %time cl0_win['cl0']=cl0G_win['cl'][corr][(0,0)].compute()
# %time cl0_win['cl']=cl0G_win['cl_b'][corr].compute()
# %time cl0_win['cov']=cl0G_win['cov'][corr+corr][(0,0,0,0)].compute()#kappa0.compute_cov_tomo(cl0G['cov'])

# %%
corr2=kappa0.cov_utils.corr_matrix(cl0['cov']['final_b'])
pcolor(lb,lb,corr2,vmin=-1,vmax=1,cmap='seismic')
xscale('log')
yscale('log')

# %%
corr2=kappa0.cov_utils.corr_matrix(cl0['cov']['final_b'])
pcolor(lb,lb,corr2,vmin=-1,vmax=1,cmap='seismic')
xscale('log')
yscale('log')

# %%
corr2=kappa0.cov_utils.corr_matrix(cl0['cov']['G_b']+cl0['cov']['Tri_b'])
pcolor(lb,lb,corr2,vmin=-1,vmax=1,cmap='seismic')
xscale('log')
yscale('log')

# %%
corr2=kappa0.cov_utils.corr_matrix(cl0['cov']['SSC_b'])
pcolor(lb,lb,corr2,vmin=-1,vmax=1,cmap='seismic')
xscale('log')
yscale('log')

# %%
cl_t=cl0['cl'][(0,0)]
plot(lb,cl_t)
# hlines(1,1,2000)
xscale('log')
yscale('log')
xlabel('$\ell$')
ylabel('$C_\ell$')
show()

# %%
cov0=cl0['cov']#[(0,0,0,0)]

f=1e4
plot(lb,np.diag(cov0['G_b'])/cl_t**2*f,label='Gaussian')
plot(lb,np.diag(cov0['SSC_b'])/cl_t**2*f,label='SSC')
plot(lb,np.diag(cov0['Tri_b'])/cl_t**2*f/lb,label='Tri')
# plot(lb,np.diag(cov0['SSC_dk'])/cl_t**2*f)
xscale('log')
yscale('log')
xlim(20,3000)
xlabel(r'$\ell$')
ylabel(r'$\frac{\delta C_\ell^2}{C_\ell^2}\times'+str(f)+'$')
legend()

# %%
plot(kappa0.cov_utils.window_l,kappa0.cov_utils.Win**2,'--')
plot(hp.alm2cl(zs_bin1[0]['window_alm']))
loglog()
ylim(.0001,10)
# Out:
# (0.0001, 10)

# %%
def matrix_cut(mat=[],x=[]):
    m=mat[x]
    N=sum(x)
    m2=np.zeros((N,N))
    j=0
    for i in m:
        m2[j]=i[x]
        j=j+1
    return m2

def SN_cum(cov=[],lb=[],cl=[],diag=False,lmin=2,use_hartlap=False,nsim=1000):
    sni=np.zeros_like(lb)
    for i in np.arange(len(lb)):
        if lb[i]<lmin:
            continue
        x=lb<=lb[i]
        x*=lb>lmin
        cov2_cut=matrix_cut(mat=cov,x=x)
        if diag:
            cov2_cut=np.diag(np.diag(cov2_cut))
        cov2_cut_inv=np.linalg.inv(cov2_cut)
        
        cl_i=cl[x]
        SN2=cl_i@cov2_cut_inv@cl_i
        if use_hartlap:
            SN2*=(nsim-2-x.sum())/(nsim-1)
        sni[i]=SN2
    return sni

# %%
sn2={}
sn2['all']=SN_cum(cov=cl0['cov']['final_b'],cl=cl0['cl'][bi],lb=lb)
sn2['G']=SN_cum(cov=cl0['cov']['G_b'],cl=cl0['cl'][bi],lb=lb)
sn2['G_SSC']=SN_cum(cov=cl0['cov']['G_b']+cl0['cov']['SSC_b'],cl=cl0['cl'][bi],lb=lb)
sn2['G_Tri']=SN_cum(cov=cl0['cov']['G_b']+cl0['cov']['Tri_b'],cl=cl0['cl'][bi],lb=lb)
sn2['G_Tri10']=SN_cum(cov=cl0['cov']['G_b']+cl0['cov']['SSC_b']+cl0['cov']['Tri_b']/10,cl=cl0['cl'][bi],lb=lb)

# %%
sn1={}
sn1['all']=SN_cum(cov=cl1['cov']['final_b'],cl=cl1['cl'][bi],lb=lb)
sn1['G']=SN_cum(cov=cl1['cov']['G_b'],cl=cl1['cl'][bi],lb=lb)
sn1['G_SSC']=SN_cum(cov=cl1['cov']['G_b']+cl1['cov']['SSC_b'],cl=cl1['cl'][bi],lb=lb)
sn1['G_Tri']=SN_cum(cov=cl1['cov']['G_b']+cl1['cov']['Tri_b'],cl=cl1['cl'][bi],lb=lb)

# %%
plot(lb,sn2['all'])
plot(lb,sn2['G'])
plot(lb,sn2['G_SSC'])
plot(lb,sn2['G_Tri'])
plot(lb,sn2['G_Tri10'],':')

plot(lb,sn1['all'],'--')
plot(lb,sn1['G'],'--')
plot(lb,sn1['G_SSC'],'--')
plot(lb,sn1['G_Tri'],'--')

loglog()
hlines(sn2['all'][-1],10,5000)
xlim(10,5000)
# Out:
# (10, 5000)
